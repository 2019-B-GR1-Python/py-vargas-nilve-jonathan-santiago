# %%
import pandas as pd
import os
# %run comida_r.ipynb
class Restaurante:
    
    
#    def __init__():
#       pass
    
    
    def mostrar_restaurante():
        try:
            df = pd.read_csv('restaurante.txt', sep=";", header=None, names=["RESTAURANTE", "UBICACION RESTAURANTE","PLATOS", "DESCRIPCION PLATO","PRECIO PLATO"])
            print(df)
            
        except:
            print("Error al mostrar el restaurante")
        return
    
    
    def ingresar_restaurante():
        #ingresa por teclado datos de la comida
        try:
            nombre_r = input("Ingrese Nombre del Restaurante: ")
            ubicacion_r = input("Ingrese la ubiacion del Restaurante: ")
       
            atributos = []
            comidas = Comida.ingresar_comida(atributos)        
        
        #f'{nombre_r};{ubicacion_r};{atributos[0]};{atributos[1]};{atributos[2]}\n'
            lista_comida = []
            lista_comida.append(f'{nombre_r};{ubicacion_r};{atributos[0]};{atributos[1]};{atributos[2]}')
    
        #ingresar datos en archivo        
            path = './restaurante.txt'
            archivo_escritura_abierto = open(path, mode="a")
            archivo_escritura_abierto.writelines([f'{nombre_r};{ubicacion_r};{atributos[0]};{atributos[1]};{atributos[2]}\n'])
            archivo_escritura_abierto.close()
            print("se ingreso correctamente")
            
        except ValueError as error:
            print("Digite numeros en el Telefono")
        except Exception as error:
            print("Error al ingresar el restaurante")
            
        return
    
    
    
    def eliminar_comida():
        buscar_por = input("ingrese nombre de la comida a eliminar: ")
        path = './restaurante.txt'
        
        #lectura del archivo
        try:
            archivo_lectura_abierto = open(path, mode="r")
            contenido = archivo_lectura_abierto.readlines()
            aux = 0
            atributos_restaurante = []
        
            for linea in contenido:
                aux +=1
                atributos_restaurante = linea.split(';')
            
                if (atributos_restaurante[2] == buscar_por):
                    contenido.pop(aux - 1)
                    print("Se elimino correctamente")
            
                else:
                    print(f"No existe la comida: {buscar_por}")
                
            archivo_lectura_abierto.close()
            
            #sobrescribir
            archivo_escritura_abierto = open(path, mode="w")
            archivo_escritura_abierto.writelines(contenido)
            archivo_escritura_abierto.close()
        except:
            print("Error al eliminar el restaurante")
    
    
    def actualizar_comida():
        buscar_por = input("Ingrese nombre de la comida a Actualizar: ")
        path = "./restaurante.txt"
        
        try:
            archivo_lectura = open(path,"r")
        
            contenido = archivo_lectura.readlines()
            aux = 0
            atributos_restaurante = []
        
            for linea in contenido:
            
                aux +=1
                atributos_restaurante = linea.split(";")
            
                if (atributos_restaurante[2] == buscar_por):

                    nombre_r = input("Ingrese Nombre del Restaurante: ")
                    ubicacion_r = input("Ingrese la ubiacion del Restaurante: ")
       
                    atributos = []
                    comidas = Comida.ingresar_comida(atributos)
                
                    contenido[aux - 1] = f'{nombre_r};{ubicacion_r};{atributos[0]};{atributos[1]};{atributos[2]}\n'
                    print("Se actualizo correctamente")
                    
                    
                
                else:
                    print(f"No existe la comida: {buscar_por}")
                    
            archivo_lectura.close()
            archivo_escritura_abierto = open(path, mode="w")
            archivo_escritura_abierto.writelines(contenido)
            archivo_escritura_abierto.close()
            
        except ValueError as error:
            print("Digite numeros en el Telefono")
        except:
            print("Error al actualizar el Restaurante")

# %%
try:
 
    
        #ingresar datos en archivo        
            path = './restaurante.txt'
            archivo_escritura_abierto = open(path, mode="a")
            archivo_escritura_abierto.writelines([f'{nombre_r};{ubicacion_r};{atributos[0]};{atributos[1]};{atributos[2]}\n'])
            archivo_escritura_abierto.close()
            print("se ingreso correctamente")

        except Exception as error:
            print("Error al ingresar el restaurante")
            
        return
